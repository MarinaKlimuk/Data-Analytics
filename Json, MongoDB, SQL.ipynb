# %% [markdown]
# # Reading and writing data

# %% [markdown]
# ## Json

# %% [markdown]
# Using the WeatherAPI service, get the weather forecast for London for the next 2 days. Convert the response to JSON format

# %%
import sqlalchemy
import psycopg2
import pandas as pd
import json
import urllib.request as req

# %%
API_KEY = "5ef71c22d1de4faab40130820240401"
days = 2
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=London&days={days}"
with req.urlopen(url) as session:
    response = session.read().decode()
    data = json.loads(response)
data
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.52,
#   'lon': -0.11,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1724342911,
#   'localtime': '2024-08-22 17:08'},
#  'current': {'last_updated_epoch': 1724342400,
#   'last_updated': '2024-08-22 17:00',
#   'temp_c': 20.3,
#   'temp_f': 68.5,
#   'is_day': 1,
#   'condition': {'text': 'Light rain',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#    'code': 1183},
#   'wind_mph': 15.0,
#   'wind_kph': 24.1,
#   'wind_degree': 220,
#   'wind_dir': 'SW',
#   'pressure_mb': 1004.0,
#   'pressure_in': 29.65,
#   'precip_mm': 0.02,
#   'precip_in': 0.0,
#   'humidity': 78,
#   'cloud': 75,
#   'feelslike_c': 20.3,
#   'feelslike_f': 68.5,
#   'windchill_c': 18.7,
#   'windchill_f': 65.7,
#   'heatindex_c': 18.7,
#   'heatindex_f': 65.7,
#   'dewpoint_c': 15.4,
#   'dewpoint_f': 59.8,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 4.0,
#   'gust_mph': 18.0,
#   'gust_kph': 29.0},
#  'forecast': {'forecastday': [{'date': '2024-08-22',
#     'date_epoch': 1724284800,
#     'day': {'maxtemp_c': 19.1,
#      'maxtemp_f': 66.4,
#      'mintemp_c': 15.7,
#      'mintemp_f': 60.2,
#      'avgtemp_c': 17.1,
#      'avgtemp_f': 62.7,
#      'maxwind_mph': 17.2,
#      'maxwind_kph': 27.7,
#      'totalprecip_mm': 0.42,
#      'totalprecip_in': 0.02,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.8,
#      'avgvis_miles': 6.0,
#      'avghumidity': 79,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 83,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain nearby',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 1.0},
#     'astro': {'sunrise': '05:58 AM',
#      'sunset': '08:08 PM',
#      'moonrise': '09:13 PM',
#      'moonset': '09:28 AM',
#      'moon_phase': 'Waning Gibbous',
#      'moon_illumination': 93},
#     'hour': [{'time_epoch': 1724281200,
#       'time': '2024-08-22 00:00',
#       'temp_c': 15.8,
#       'temp_f': 60.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 43,
#       'feelslike_c': 15.8,
#       'feelslike_f': 60.5,
#       'windchill_c': 15.8,
#       'windchill_f': 60.5,
#       'heatindex_c': 15.8,
#       'heatindex_f': 60.5,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.4,
#       'gust_kph': 26.4,
#       'uv': 0},
#      {'time_epoch': 1724284800,
#       'time': '2024-08-22 01:00',
#       'temp_c': 15.7,
#       'temp_f': 60.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 215,
#       'wind_dir': 'SW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 45,
#       'feelslike_c': 15.7,
#       'feelslike_f': 60.2,
#       'windchill_c': 15.7,
#       'windchill_f': 60.2,
#       'heatindex_c': 15.7,
#       'heatindex_f': 60.2,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.7,
#       'gust_kph': 28.5,
#       'uv': 0},
#      {'time_epoch': 1724288400,
#       'time': '2024-08-22 02:00',
#       'temp_c': 15.7,
#       'temp_f': 60.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 12.8,
#       'wind_kph': 20.5,
#       'wind_degree': 214,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 31,
#       'feelslike_c': 15.7,
#       'feelslike_f': 60.2,
#       'windchill_c': 15.7,
#       'windchill_f': 60.2,
#       'heatindex_c': 15.7,
#       'heatindex_f': 60.2,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.5,
#       'gust_kph': 29.8,
#       'uv': 0},
#      {'time_epoch': 1724292000,
#       'time': '2024-08-22 03:00',
#       'temp_c': 15.7,
#       'temp_f': 60.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 13.4,
#       'wind_kph': 21.6,
#       'wind_degree': 216,
#       'wind_dir': 'SW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 37,
#       'feelslike_c': 15.7,
#       'feelslike_f': 60.2,
#       'windchill_c': 15.7,
#       'windchill_f': 60.2,
#       'heatindex_c': 15.7,
#       'heatindex_f': 60.2,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.7,
#       'gust_kph': 31.8,
#       'uv': 0},
#      {'time_epoch': 1724295600,
#       'time': '2024-08-22 04:00',
#       'temp_c': 15.7,
#       'temp_f': 60.2,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 14.5,
#       'wind_kph': 23.4,
#       'wind_degree': 217,
#       'wind_dir': 'SW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.81,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 67,
#       'feelslike_c': 15.7,
#       'feelslike_f': 60.2,
#       'windchill_c': 15.7,
#       'windchill_f': 60.2,
#       'heatindex_c': 15.7,
#       'heatindex_f': 60.2,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.4,
#       'gust_kph': 34.4,
#       'uv': 0},
#      {'time_epoch': 1724299200,
#       'time': '2024-08-22 05:00',
#       'temp_c': 15.9,
#       'temp_f': 60.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 16.1,
#       'wind_kph': 25.9,
#       'wind_degree': 212,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.79,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 49,
#       'feelslike_c': 15.9,
#       'feelslike_f': 60.6,
#       'windchill_c': 15.9,
#       'windchill_f': 60.6,
#       'heatindex_c': 15.9,
#       'heatindex_f': 60.6,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 23.3,
#       'gust_kph': 37.5,
#       'uv': 0},
#      {'time_epoch': 1724302800,
#       'time': '2024-08-22 06:00',
#       'temp_c': 16.0,
#       'temp_f': 60.9,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 15.7,
#       'wind_kph': 25.2,
#       'wind_degree': 213,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.77,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 81,
#       'feelslike_c': 16.0,
#       'feelslike_f': 60.9,
#       'windchill_c': 16.0,
#       'windchill_f': 60.9,
#       'heatindex_c': 16.0,
#       'heatindex_f': 60.9,
#       'dewpoint_c': 11.6,
#       'dewpoint_f': 52.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 22.1,
#       'gust_kph': 35.6,
#       'uv': 4.0},
#      {'time_epoch': 1724306400,
#       'time': '2024-08-22 07:00',
#       'temp_c': 16.6,
#       'temp_f': 61.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/263.png',
#        'code': 1150},
#       'wind_mph': 15.7,
#       'wind_kph': 25.2,
#       'wind_degree': 213,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.75,
#       'precip_mm': 0.24,
#       'precip_in': 0.01,
#       'humidity': 74,
#       'cloud': 71,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.9,
#       'windchill_c': 16.6,
#       'windchill_f': 61.9,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.9,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 5.0,
#       'vis_miles': 3.0,
#       'gust_mph': 20.7,
#       'gust_kph': 33.3,
#       'uv': 4.0},
#      {'time_epoch': 1724310000,
#       'time': '2024-08-22 08:00',
#       'temp_c': 16.6,
#       'temp_f': 61.9,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 17.0,
#       'wind_kph': 27.4,
#       'wind_degree': 212,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.74,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 70,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.9,
#       'windchill_c': 16.6,
#       'windchill_f': 61.9,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.9,
#       'dewpoint_c': 12.7,
#       'dewpoint_f': 54.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 23.5,
#       'gust_kph': 37.8,
#       'uv': 4.0},
#      {'time_epoch': 1724313600,
#       'time': '2024-08-22 09:00',
#       'temp_c': 17.0,
#       'temp_f': 62.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 17.2,
#       'wind_kph': 27.7,
#       'wind_degree': 217,
#       'wind_dir': 'SW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.75,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 100,
#       'feelslike_c': 17.0,
#       'feelslike_f': 62.6,
#       'windchill_c': 17.0,
#       'windchill_f': 62.6,
#       'heatindex_c': 17.0,
#       'heatindex_f': 62.6,
#       'dewpoint_c': 13.0,
#       'dewpoint_f': 55.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 23.6,
#       'gust_kph': 38.0,
#       'uv': 4.0},
#      {'time_epoch': 1724317200,
#       'time': '2024-08-22 10:00',
#       'temp_c': 17.2,
#       'temp_f': 62.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 16.3,
#       'wind_kph': 26.3,
#       'wind_degree': 217,
#       'wind_dir': 'SW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.75,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 100,
#       'feelslike_c': 17.2,
#       'feelslike_f': 62.9,
#       'windchill_c': 17.2,
#       'windchill_f': 62.9,
#       'heatindex_c': 17.2,
#       'heatindex_f': 62.9,
#       'dewpoint_c': 13.2,
#       'dewpoint_f': 55.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 66,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 22.5,
#       'gust_kph': 36.3,
#       'uv': 4.0},
#      {'time_epoch': 1724320800,
#       'time': '2024-08-22 11:00',
#       'temp_c': 17.5,
#       'temp_f': 63.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 16.6,
#       'wind_kph': 26.6,
#       'wind_degree': 215,
#       'wind_dir': 'SW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.73,
#       'precip_mm': 0.07,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 100,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.6,
#       'windchill_c': 17.5,
#       'windchill_f': 63.6,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.6,
#       'dewpoint_c': 13.8,
#       'dewpoint_f': 56.9,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.8,
#       'gust_kph': 35.1,
#       'uv': 4.0},
#      {'time_epoch': 1724324400,
#       'time': '2024-08-22 12:00',
#       'temp_c': 17.3,
#       'temp_f': 63.2,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 16.1,
#       'wind_kph': 25.9,
#       'wind_degree': 215,
#       'wind_dir': 'SW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.72,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.2,
#       'windchill_c': 17.3,
#       'windchill_f': 63.2,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.2,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 76,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 22.1,
#       'gust_kph': 35.6,
#       'uv': 4.0},
#      {'time_epoch': 1724328000,
#       'time': '2024-08-22 13:00',
#       'temp_c': 17.3,
#       'temp_f': 63.2,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 15.7,
#       'wind_kph': 25.2,
#       'wind_degree': 215,
#       'wind_dir': 'SW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.72,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.2,
#       'windchill_c': 17.3,
#       'windchill_f': 63.2,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.2,
#       'dewpoint_c': 14.6,
#       'dewpoint_f': 58.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.3,
#       'gust_kph': 34.3,
#       'uv': 4.0},
#      {'time_epoch': 1724331600,
#       'time': '2024-08-22 14:00',
#       'temp_c': 17.8,
#       'temp_f': 64.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 14.8,
#       'wind_kph': 23.8,
#       'wind_degree': 218,
#       'wind_dir': 'SW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.0,
#       'windchill_c': 17.8,
#       'windchill_f': 64.0,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.0,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 58.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.4,
#       'gust_kph': 31.2,
#       'uv': 4.0},
#      {'time_epoch': 1724335200,
#       'time': '2024-08-22 15:00',
#       'temp_c': 17.8,
#       'temp_f': 64.1,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 14.1,
#       'wind_kph': 22.7,
#       'wind_degree': 219,
#       'wind_dir': 'SW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 100,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.1,
#       'windchill_c': 17.8,
#       'windchill_f': 64.1,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.1,
#       'dewpoint_c': 15.4,
#       'dewpoint_f': 59.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.6,
#       'gust_kph': 30.0,
#       'uv': 4.0},
#      {'time_epoch': 1724338800,
#       'time': '2024-08-22 16:00',
#       'temp_c': 18.0,
#       'temp_f': 64.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 13.4,
#       'wind_kph': 21.6,
#       'wind_degree': 219,
#       'wind_dir': 'SW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 100,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.5,
#       'windchill_c': 18.0,
#       'windchill_f': 64.5,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.5,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 66,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.1,
#       'gust_kph': 29.1,
#       'uv': 4.0},
#      {'time_epoch': 1724342400,
#       'time': '2024-08-22 17:00',
#       'temp_c': 20.3,
#       'temp_f': 68.5,
#       'is_day': 1,
#       'condition': {'text': 'Light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#        'code': 1183},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.65,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 75,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.7,
#       'windchill_c': 18.7,
#       'windchill_f': 65.7,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.7,
#       'dewpoint_c': 15.4,
#       'dewpoint_f': 59.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 74,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.0,
#       'gust_kph': 29.0,
#       'uv': 4.0},
#      {'time_epoch': 1724346000,
#       'time': '2024-08-22 18:00',
#       'temp_c': 19.1,
#       'temp_f': 66.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.8,
#       'wind_kph': 20.5,
#       'wind_degree': 218,
#       'wind_dir': 'SW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.68,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 85,
#       'feelslike_c': 19.1,
#       'feelslike_f': 66.4,
#       'windchill_c': 19.1,
#       'windchill_f': 66.4,
#       'heatindex_c': 19.1,
#       'heatindex_f': 66.4,
#       'dewpoint_c': 15.4,
#       'dewpoint_f': 59.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 66,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.4,
#       'gust_kph': 28.0,
#       'uv': 4.0},
#      {'time_epoch': 1724349600,
#       'time': '2024-08-22 19:00',
#       'temp_c': 18.5,
#       'temp_f': 65.3,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 218,
#       'wind_dir': 'SW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.68,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 66,
#       'feelslike_c': 18.5,
#       'feelslike_f': 65.3,
#       'windchill_c': 18.5,
#       'windchill_f': 65.3,
#       'heatindex_c': 18.5,
#       'heatindex_f': 65.3,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 59.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.4,
#       'gust_kph': 29.6,
#       'uv': 4.0},
#      {'time_epoch': 1724353200,
#       'time': '2024-08-22 20:00',
#       'temp_c': 17.9,
#       'temp_f': 64.1,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 223,
#       'wind_dir': 'SW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 82,
#       'feelslike_c': 17.9,
#       'feelslike_f': 64.1,
#       'windchill_c': 17.9,
#       'windchill_f': 64.1,
#       'heatindex_c': 17.9,
#       'heatindex_f': 64.1,
#       'dewpoint_c': 14.7,
#       'dewpoint_f': 58.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.1,
#       'gust_kph': 27.6,
#       'uv': 4.0},
#      {'time_epoch': 1724356800,
#       'time': '2024-08-22 21:00',
#       'temp_c': 17.5,
#       'temp_f': 63.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 226,
#       'wind_dir': 'SW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.68,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 59,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.6,
#       'windchill_c': 17.5,
#       'windchill_f': 63.6,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.6,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.7,
#       'gust_kph': 25.3,
#       'uv': 0},
#      {'time_epoch': 1724360400,
#       'time': '2024-08-22 22:00',
#       'temp_c': 17.2,
#       'temp_f': 63.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 219,
#       'wind_dir': 'SW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.66,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 39,
#       'feelslike_c': 17.2,
#       'feelslike_f': 63.0,
#       'windchill_c': 17.2,
#       'windchill_f': 63.0,
#       'heatindex_c': 17.2,
#       'heatindex_f': 63.0,
#       'dewpoint_c': 13.3,
#       'dewpoint_f': 56.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.6,
#       'gust_kph': 26.6,
#       'uv': 0},
#      {'time_epoch': 1724364000,
#       'time': '2024-08-22 23:00',
#       'temp_c': 17.1,
#       'temp_f': 62.8,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.64,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 40,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.8,
#       'windchill_c': 17.1,
#       'windchill_f': 62.8,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.8,
#       'dewpoint_c': 13.0,
#       'dewpoint_f': 55.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.6,
#       'gust_kph': 28.3,
#       'uv': 0}]},
#    {'date': '2024-08-23',
#     'date_epoch': 1724371200,
#     'day': {'maxtemp_c': 22.4,
#      'maxtemp_f': 72.4,
#      'mintemp_c': 16.4,
#      'mintemp_f': 61.6,
#      'avgtemp_c': 19.0,
#      'avgtemp_f': 66.2,
#      'maxwind_mph': 19.5,
#      'maxwind_kph': 31.3,
#      'totalprecip_mm': 0.57,
#      'totalprecip_in': 0.02,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.7,
#      'avgvis_miles': 6.0,
#      'avghumidity': 60,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 76,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain nearby',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 6.0},
#     'astro': {'sunrise': '05:59 AM',
#      'sunset': '08:05 PM',
#      'moonrise': '09:27 PM',
#      'moonset': '10:57 AM',
#      'moon_phase': 'Waning Gibbous',
#      'moon_illumination': 85},
#     'hour': [{'time_epoch': 1724367600,
#       'time': '2024-08-23 00:00',
#       'temp_c': 17.0,
#       'temp_f': 62.6,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.63,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': 17.0,
#       'feelslike_f': 62.6,
#       'windchill_c': 17.0,
#       'windchill_f': 62.6,
#       'heatindex_c': 17.0,
#       'heatindex_f': 62.6,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 70,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.2,
#       'gust_kph': 27.8,
#       'uv': 0},
#      {'time_epoch': 1724371200,
#       'time': '2024-08-23 01:00',
#       'temp_c': 17.5,
#       'temp_f': 63.6,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 14.5,
#       'wind_kph': 23.4,
#       'wind_degree': 214,
#       'wind_dir': 'SW',
#       'pressure_mb': 1002.0,
#       'pressure_in': 29.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 90,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.6,
#       'windchill_c': 17.6,
#       'windchill_f': 63.6,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.6,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.6,
#       'gust_kph': 33.2,
#       'uv': 0},
#      {'time_epoch': 1724374800,
#       'time': '2024-08-23 02:00',
#       'temp_c': 17.0,
#       'temp_f': 62.6,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 16.1,
#       'wind_kph': 25.9,
#       'wind_degree': 211,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.57,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 72,
#       'feelslike_c': 17.0,
#       'feelslike_f': 62.7,
#       'windchill_c': 17.0,
#       'windchill_f': 62.7,
#       'heatindex_c': 17.0,
#       'heatindex_f': 62.7,
#       'dewpoint_c': 13.7,
#       'dewpoint_f': 56.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 23.4,
#       'gust_kph': 37.7,
#       'uv': 0},
#      {'time_epoch': 1724378400,
#       'time': '2024-08-23 03:00',
#       'temp_c': 17.3,
#       'temp_f': 63.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 17.4,
#       'wind_kph': 28.1,
#       'wind_degree': 212,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1000.0,
#       'pressure_in': 29.54,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.1,
#       'windchill_c': 17.3,
#       'windchill_f': 63.1,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.1,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 25.8,
#       'gust_kph': 41.5,
#       'uv': 0},
#      {'time_epoch': 1724382000,
#       'time': '2024-08-23 04:00',
#       'temp_c': 17.7,
#       'temp_f': 63.9,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 18.3,
#       'wind_kph': 29.5,
#       'wind_degree': 213,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1000.0,
#       'pressure_in': 29.52,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.0,
#       'windchill_c': 17.8,
#       'windchill_f': 64.0,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.0,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 27.0,
#       'gust_kph': 43.5,
#       'uv': 0},
#      {'time_epoch': 1724385600,
#       'time': '2024-08-23 05:00',
#       'temp_c': 17.9,
#       'temp_f': 64.2,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 19.0,
#       'wind_kph': 30.6,
#       'wind_degree': 213,
#       'wind_dir': 'SSW',
#       'pressure_mb': 999.0,
#       'pressure_in': 29.51,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 100,
#       'feelslike_c': 17.9,
#       'feelslike_f': 64.2,
#       'windchill_c': 17.9,
#       'windchill_f': 64.2,
#       'heatindex_c': 17.9,
#       'heatindex_f': 64.2,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 70,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 27.4,
#       'gust_kph': 44.2,
#       'uv': 0},
#      {'time_epoch': 1724389200,
#       'time': '2024-08-23 06:00',
#       'temp_c': 17.8,
#       'temp_f': 64.0,
#       'is_day': 1,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/266.png',
#        'code': 1153},
#       'wind_mph': 19.5,
#       'wind_kph': 31.3,
#       'wind_degree': 218,
#       'wind_dir': 'SW',
#       'pressure_mb': 999.0,
#       'pressure_in': 29.51,
#       'precip_mm': 0.35,
#       'precip_in': 0.01,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.0,
#       'windchill_c': 17.8,
#       'windchill_f': 64.0,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.0,
#       'dewpoint_c': 15.1,
#       'dewpoint_f': 59.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 27.5,
#       'gust_kph': 44.3,
#       'uv': 4.0},
#      {'time_epoch': 1724392800,
#       'time': '2024-08-23 07:00',
#       'temp_c': 17.9,
#       'temp_f': 64.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 19.5,
#       'wind_kph': 31.3,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 1000.0,
#       'pressure_in': 29.52,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 100,
#       'feelslike_c': 17.9,
#       'feelslike_f': 64.1,
#       'windchill_c': 17.9,
#       'windchill_f': 64.1,
#       'heatindex_c': 17.9,
#       'heatindex_f': 64.1,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 76,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 28.0,
#       'gust_kph': 45.0,
#       'uv': 4.0},
#      {'time_epoch': 1724396400,
#       'time': '2024-08-23 08:00',
#       'temp_c': 18.1,
#       'temp_f': 64.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 17.9,
#       'wind_kph': 28.8,
#       'wind_degree': 255,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.57,
#       'precip_mm': 0.15,
#       'precip_in': 0.01,
#       'humidity': 82,
#       'cloud': 61,
#       'feelslike_c': 18.2,
#       'feelslike_f': 64.7,
#       'windchill_c': 18.2,
#       'windchill_f': 64.7,
#       'heatindex_c': 18.2,
#       'heatindex_f': 64.7,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 59.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 25.4,
#       'gust_kph': 40.9,
#       'uv': 4.0},
#      {'time_epoch': 1724400000,
#       'time': '2024-08-23 09:00',
#       'temp_c': 19.0,
#       'temp_f': 66.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 15.7,
#       'wind_kph': 25.2,
#       'wind_degree': 262,
#       'wind_dir': 'W',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.61,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 60,
#       'cloud': 11,
#       'feelslike_c': 19.0,
#       'feelslike_f': 66.3,
#       'windchill_c': 19.0,
#       'windchill_f': 66.3,
#       'heatindex_c': 19.0,
#       'heatindex_f': 66.3,
#       'dewpoint_c': 11.2,
#       'dewpoint_f': 52.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.0,
#       'gust_kph': 29.0,
#       'uv': 5.0},
#      {'time_epoch': 1724403600,
#       'time': '2024-08-23 10:00',
#       'temp_c': 20.1,
#       'temp_f': 68.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 16.1,
#       'wind_kph': 25.9,
#       'wind_degree': 267,
#       'wind_dir': 'W',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.65,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 48,
#       'cloud': 10,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.1,
#       'windchill_c': 20.1,
#       'windchill_f': 68.1,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.1,
#       'dewpoint_c': 8.6,
#       'dewpoint_f': 47.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.5,
#       'gust_kph': 29.8,
#       'uv': 6.0},
#      {'time_epoch': 1724407200,
#       'time': '2024-08-23 11:00',
#       'temp_c': 20.6,
#       'temp_f': 69.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 14.8,
#       'wind_kph': 23.8,
#       'wind_degree': 271,
#       'wind_dir': 'W',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.67,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 41,
#       'cloud': 9,
#       'feelslike_c': 20.6,
#       'feelslike_f': 69.1,
#       'windchill_c': 20.6,
#       'windchill_f': 69.1,
#       'heatindex_c': 20.6,
#       'heatindex_f': 69.1,
#       'dewpoint_c': 7.0,
#       'dewpoint_f': 44.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.3,
#       'uv': 6.0},
#      {'time_epoch': 1724410800,
#       'time': '2024-08-23 12:00',
#       'temp_c': 21.1,
#       'temp_f': 70.0,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 13.4,
#       'wind_kph': 21.6,
#       'wind_degree': 268,
#       'wind_dir': 'W',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 37,
#       'cloud': 82,
#       'feelslike_c': 21.1,
#       'feelslike_f': 70.0,
#       'windchill_c': 21.1,
#       'windchill_f': 70.0,
#       'heatindex_c': 23.6,
#       'heatindex_f': 74.5,
#       'dewpoint_c': 5.9,
#       'dewpoint_f': 42.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 5.0},
#      {'time_epoch': 1724414400,
#       'time': '2024-08-23 13:00',
#       'temp_c': 21.7,
#       'temp_f': 71.1,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 34,
#       'cloud': 100,
#       'feelslike_c': 21.7,
#       'feelslike_f': 71.1,
#       'windchill_c': 21.7,
#       'windchill_f': 71.1,
#       'heatindex_c': 23.6,
#       'heatindex_f': 74.4,
#       'dewpoint_c': 5.3,
#       'dewpoint_f': 41.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.6,
#       'gust_kph': 22.0,
#       'uv': 5.0},
#      {'time_epoch': 1724418000,
#       'time': '2024-08-23 14:00',
#       'temp_c': 22.3,
#       'temp_f': 72.2,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 256,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 32,
#       'cloud': 72,
#       'feelslike_c': 23.6,
#       'feelslike_f': 74.5,
#       'windchill_c': 22.3,
#       'windchill_f': 72.2,
#       'heatindex_c': 23.6,
#       'heatindex_f': 74.5,
#       'dewpoint_c': 5.0,
#       'dewpoint_f': 41.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 5.0},
#      {'time_epoch': 1724421600,
#       'time': '2024-08-23 15:00',
#       'temp_c': 22.4,
#       'temp_f': 72.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 253,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 32,
#       'cloud': 13,
#       'feelslike_c': 23.6,
#       'feelslike_f': 74.5,
#       'windchill_c': 22.4,
#       'windchill_f': 72.4,
#       'heatindex_c': 23.6,
#       'heatindex_f': 74.5,
#       'dewpoint_c': 5.0,
#       'dewpoint_f': 41.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.9,
#       'gust_kph': 20.7,
#       'uv': 6.0},
#      {'time_epoch': 1724425200,
#       'time': '2024-08-23 16:00',
#       'temp_c': 22.2,
#       'temp_f': 72.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 250,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 33,
#       'cloud': 24,
#       'feelslike_c': 23.7,
#       'feelslike_f': 74.6,
#       'windchill_c': 22.3,
#       'windchill_f': 72.1,
#       'heatindex_c': 23.7,
#       'heatindex_f': 74.6,
#       'dewpoint_c': 5.4,
#       'dewpoint_f': 41.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.9,
#       'gust_kph': 20.7,
#       'uv': 6.0},
#      {'time_epoch': 1724428800,
#       'time': '2024-08-23 17:00',
#       'temp_c': 21.7,
#       'temp_f': 71.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 251,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 36,
#       'cloud': 25,
#       'feelslike_c': 21.7,
#       'feelslike_f': 71.1,
#       'windchill_c': 21.7,
#       'windchill_f': 71.1,
#       'heatindex_c': 23.7,
#       'heatindex_f': 74.7,
#       'dewpoint_c': 6.1,
#       'dewpoint_f': 42.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.6,
#       'uv': 6.0},
#      {'time_epoch': 1724432400,
#       'time': '2024-08-23 18:00',
#       'temp_c': 20.8,
#       'temp_f': 69.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 227,
#       'wind_dir': 'SW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 42,
#       'cloud': 23,
#       'feelslike_c': 20.8,
#       'feelslike_f': 69.5,
#       'windchill_c': 20.8,
#       'windchill_f': 69.5,
#       'heatindex_c': 20.8,
#       'heatindex_f': 69.5,
#       'dewpoint_c': 7.5,
#       'dewpoint_f': 45.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.4,
#       'gust_kph': 20.0,
#       'uv': 6.0},
#      {'time_epoch': 1724436000,
#       'time': '2024-08-23 19:00',
#       'temp_c': 18.4,
#       'temp_f': 65.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.0,
#       'wind_kph': 17.6,
#       'wind_degree': 217,
#       'wind_dir': 'SW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.74,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 54,
#       'cloud': 24,
#       'feelslike_c': 18.4,
#       'feelslike_f': 65.2,
#       'windchill_c': 18.4,
#       'windchill_f': 65.2,
#       'heatindex_c': 18.4,
#       'heatindex_f': 65.2,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.9,
#       'gust_kph': 23.9,
#       'uv': 5.0},
#      {'time_epoch': 1724439600,
#       'time': '2024-08-23 20:00',
#       'temp_c': 17.3,
#       'temp_f': 63.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 224,
#       'wind_dir': 'SW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.76,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 60,
#       'cloud': 54,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.2,
#       'windchill_c': 17.3,
#       'windchill_f': 63.2,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.2,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 48.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.6,
#       'uv': 5.0},
#      {'time_epoch': 1724443200,
#       'time': '2024-08-23 21:00',
#       'temp_c': 16.8,
#       'temp_f': 62.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 229,
#       'wind_dir': 'SW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.76,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 49,
#       'feelslike_c': 16.8,
#       'feelslike_f': 62.3,
#       'windchill_c': 16.8,
#       'windchill_f': 62.3,
#       'heatindex_c': 16.8,
#       'heatindex_f': 62.3,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 0},
#      {'time_epoch': 1724446800,
#       'time': '2024-08-23 22:00',
#       'temp_c': 16.6,
#       'temp_f': 61.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.75,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 13,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.9,
#       'windchill_c': 16.6,
#       'windchill_f': 61.9,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.9,
#       'dewpoint_c': 9.9,
#       'dewpoint_f': 49.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.7,
#       'gust_kph': 18.9,
#       'uv': 0},
#      {'time_epoch': 1724450400,
#       'time': '2024-08-23 23:00',
#       'temp_c': 16.4,
#       'temp_f': 61.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.74,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 45,
#       'feelslike_c': 16.4,
#       'feelslike_f': 61.6,
#       'windchill_c': 16.4,
#       'windchill_f': 61.6,
#       'heatindex_c': 16.4,
#       'heatindex_f': 61.6,
#       'dewpoint_c': 9.9,
#       'dewpoint_f': 49.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.7,
#       'gust_kph': 18.8,
#       'uv': 0}]}]}}

# %% [markdown]
# Save the weather data obtained from the previous task to a file named weather.json. Use four spaces for formatting.

# %%
with open('weather.json', 'w') as file:
    json.dump(data, file, indent = 4)

# %% [markdown]
# From the contents of the weather.json file, extract the hourly weather forecast, load it into a DataFrame, and display the first five rows of the DataFrame.

# %%
df = pd.read_json('weather.json')
df['forecast']['forecastday']

d = []

for i in range(days):
    d_outer = df['forecast']['forecastday'][i]
    d = d + d_outer['hour']
    
df = pd.DataFrame(d)
df.head()
# Out:
#    time_epoch              time  temp_c  temp_f  is_day  \
# 0  1724281200  2024-08-22 00:00    15.8    60.5       0
# 1  1724284800  2024-08-22 01:00    15.7    60.2       0
# 2  1724288400  2024-08-22 02:00    15.7    60.2       0
# 3  1724292000  2024-08-22 03:00    15.7    60.2       0
# 4  1724295600  2024-08-22 04:00    15.7    60.2       0
#
#                                            condition  wind_mph  wind_kph  \
# 0  {'text': 'Partly Cloudy ', 'icon': '//cdn.weat...      11.6      18.7
# 1  {'text': 'Partly Cloudy ', 'icon': '//cdn.weat...      12.3      19.8
# 2  {'text': 'Partly Cloudy ', 'icon': '//cdn.weat...      12.8      20.5
# 3  {'text': 'Partly Cloudy ', 'icon': '//cdn.weat...      13.4      21.6
# 4  {'text': 'Cloudy ', 'icon': '//cdn.weatherapi....      14.5      23.4
#
#    wind_degree wind_dir  ...  dewpoint_f  will_it_rain  chance_of_rain  \
# 0          220       SW  ...        52.4             0               0
# 1          215       SW  ...        52.7             0               0
# 2          214       SW  ...        52.6             0               0
# 3          216       SW  ...        52.5             0               0
# 4          217       SW  ...        52.6             0               0
#
#    will_it_snow  chance_of_snow  vis_km  vis_miles  gust_mph  gust_kph   uv
# 0             0               0    10.0        6.0      16.4      26.4  0.0
# 1             0               0    10.0        6.0      17.7      28.5  0.0
# 2             0               0    10.0        6.0      18.5      29.8  0.0
# 3             0               0    10.0        6.0      19.7      31.8  0.0
# 4             0               0    10.0        6.0      21.4      34.4  0.0
#
# [5 rows x 33 columns]

# %% [markdown]
# Save the DataFrame from the previous task to a file named result.csv. Use index as the name for the index column.

# %%
df.to_csv('result.csv', index_label = 'index')

# %% [markdown]
# ### SQL & MongoDB
#
# Load the contents of the SQL table ratings into a DataFrame. Display the first five rows of the DataFrame. Use the connection string provided in the following cell to connect to the database.

# %%
connection = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'
engine = sqlalchemy.create_engine(connection)
connect = engine.connect()
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
df2 = pd.read_sql('select * from ratings', connect)
df2.head()
# Out:
#    userid  movieid  rating   timestamp
# 0    6328    60069     5.0  1446643353
# 1    6328    91658     5.0  1446643397
# 2    6328    92259     5.0  1446643521
# 3    6328    97913     5.0  1446643624
# 4    6328   109374     5.0  1446643535

# %% [markdown]
# Save the first 10,000 records of the DataFrame from the previous task to a file named result2.xlsx, and name the sheet MySheet.

# %%
df2 = df2.head(10000)
df2.to_excel('result2.xlsx',sheet_name = 'MySheet')

# %% [markdown]
# Determine the number of documents in the users collection in MongoDB. If the number of documents is less than 1,000, in the next cell, load the entire contents of this collection into a list and display the first element of this list. Use the connection string provided in the following cell to connect to MongoDB.

# %%
import pymongo
conn = 'mongodb://students:X63673t47Gl03Sq@dsstudents.skillbox.ru:27017/?authSource=movies'
connect = pymongo.MongoClient(conn)
db = connect['movies']
db.list_collection_names()
users = db['users']
users.count_documents({})
# Out:
# 102

# %%
data = users.find()
users_list = list(data)
users_list[0]
# Out:
# {'_id': ObjectId('5cc69095067496679c74f7a4'),
#  'user_id': 'ed5da480-57a2-489c-8e68-512155ab9892',
#  'first_name': 'Жанна',
#  'last_name': 'Петрова',
#  'mail': 'zhanna_03816@gmail.com',
#  'age': 20.0}

# %% [markdown]
# ## Additional tasks
#
# Using the data from the SQL table ratings, determine the average rating given by each user (column userid). Display the results on the screen. Perform the grouping in two ways: using GROUP BY in the SQL query and using the groupby method in pandas.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'
engine = sqlalchemy.create_engine(conn)
connect = engine.connect()
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['links',
#  'joi',
#  'mobile',
#  'new_table',
#  'course_purchases',
#  'orders',
#  'sales',
#  'exploratory',
#  'studentt',
#  'superheroes',
#  'users',
#  'product_types',
#  'products',
#  'ratings',
#  'keywords',
#  'course_purchases_1']

# %%
df = pd.read_sql('select userid, AVG(rating) from ratings group by userid', connect)
df.head()
# Out:
#    userid       avg
# 0    6114  4.000000
# 1    4790  4.000000
# 2     273  4.314685
# 3    3936  3.756757
# 4    5761  3.419220

# %%
df = pd.read_sql('select * from ratings', connect)
df = df.groupby('userid')[ 'rating'].mean()
df.head()
# Out:
# userid
# 1    4.277778
# 2    3.318182
# 3    3.100000
# 4    3.500000
# 5    4.269231
# Name: rating, dtype: float64

# %% [markdown]
# Join the ratings and keywords tables on the movieid columns (using a left join). Perform the join in two ways: using LEFT JOIN in the SQL query and using the merge method in pandas. Load the result into a DataFrame and save it to a file named result4.csv.
# Note that there might be duplicate columns after the join. Ensure that the resulting DataFrame does not contain any duplicated columns.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'
engine = sqlalchemy.create_engine(conn)
connect = engine.connect()
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
df1 = pd.read_sql('select * from ratings', connect)
df1.head()
# Out:
#    userid  movieid  rating   timestamp
# 0    6328    60069     5.0  1446643353
# 1    6328    91658     5.0  1446643397
# 2    6328    92259     5.0  1446643521
# 3    6328    97913     5.0  1446643624
# 4    6328   109374     5.0  1446643535

# %%
df2 = pd.read_sql('select * from keywords', connect)
df2.head()
# Out:
#    movieid                                               tags
# 0      862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2    15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3    31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4    11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df3 = pd.read_sql('select * from ratings left join keywords on ratings.movieid = keywords.movieid ', connect)
df3 = df3.loc[:, ~df3.columns.duplicated()]
df3.head()
# Out:
#    userid  movieid  rating   timestamp  tags
# 0    6513     3702     3.0  1086467930  None
# 1    6513     3703     3.5  1086467905  None
# 2    6513     3740     3.0  1146066023  None
# 3    6513     3752     3.0  1146068196  None
# 4    6513     3755     2.5  1086523172  None

# %%
df4 = pd.merge(df1,df2, on = 'movieid', how = 'left')
df4.head()
# Out:
#    userid  movieid  rating   timestamp tags
# 0    6328    60069     5.0  1446643353  NaN
# 1    6328    91658     5.0  1446643397  NaN
# 2    6328    92259     5.0  1446643521  NaN
# 3    6328    97913     5.0  1446643624  NaN
# 4    6328   109374     5.0  1446643535  NaN

# %%
df4.to_csv('result4')

# %% [markdown]
# Using the joined table from the previous task, find all movie identifiers with the tag africa (but not south africa or any other tags). The list of tags in JSON format is stored in the tags column.

# %%
df4
df4 = df4.dropna().reset_index()
del df4['index']

# %%
df4
# Out:
#          userid  movieid  rating   timestamp  \
# 0          6329      272     5.0  1024025336
# 1          6329      272     5.0  1024025336
# 2          6329      551     5.0  1024025315
# 3          6329      551     5.0  1024025315
# 4          6329      631     1.0  1024025262
# ...         ...      ...     ...         ...
# 1361271    6328     4011     5.0  1446643461
# 1361272    6328     4973     5.0  1446643523
# 1361273    6328     4973     5.0  1446643523
# 1361274    6328     5995     4.5  1446643255
# 1361275    6328     5995     4.5  1446643255
#
#                                                       tags
# 0        [{'id': 486, 'name': 'himalaya'}, {'id': 779, ...
# 1        [{'id': 486, 'name': 'himalaya'}, {'id': 779, ...
# 2        [{'id': 314, 'name': 'life and death'}, {'id':...
# 3        [{'id': 314, 'name': 'life and death'}, {'id':...
# 4        [{'id': 128, 'name': 'love triangle'}, {'id': ...
# ...                                                    ...
# 1361271  [{'id': 3065, 'name': 'minister'}, {'id': 3891...
# 1361272  [{'id': 966, 'name': 'beach'}, {'id': 1157, 'n...
# 1361273  [{'id': 966, 'name': 'beach'}, {'id': 1157, 'n...
# 1361274  [{'id': 1192, 'name': 'sweden'}, {'id': 1605, ...
# 1361275  [{'id': 1192, 'name': 'sweden'}, {'id': 1605, ...
#
# [1361276 rows x 5 columns]

# %%
index_list = []
for i in range(len(df4)):
    if "'name': 'africa'" in df4['tags'][i]:
        index = df4['movieid'][i]
        if index not in index_list:
            index_list.append(index)
print("Film's ID:", end = ' ')
for i in index_list:
    print(i, end = ' ')
# Out:
# Film's ID: 494 179 1672 2197 2989 488 38198 4274 4460 7010 25874 873 8929 46207
